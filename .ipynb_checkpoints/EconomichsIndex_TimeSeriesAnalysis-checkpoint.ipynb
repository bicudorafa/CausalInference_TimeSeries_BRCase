# %% [markdown]
# ### Data Extraction

# %%
import pandas as pd
# Biblioteca que gera reports automaticos
import pandas_profiling as pp
import statsmodels.api as sm
import numpy as np
import seaborn as sns
import gc
import matplotlib.pyplot as plt
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')
# Ajuda a otimizar o uso da memória
gc.enable()

# %%
ibov = pd.read_csv('^BVSP.csv')
print(ibov.dtypes)
ibov.head()
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object
#          Date     Open     High      Low    Close  Adj Close     Volume
# 0  2009-01-02  37550.0  40265.0  37550.0  40244.0    40244.0  1055200.0
# 1  2009-01-05  40243.0  41889.0  39526.0  41519.0    41519.0  1909200.0
# 2  2009-01-06  41520.0  42363.0  41520.0  42312.0    42312.0  1791000.0
# 3  2009-01-07  42308.0  42308.0  40563.0  40820.0    40820.0  1383600.0
# 4  2009-01-08  40819.0  41991.0  40251.0  41991.0    41991.0  1556000.0

# %%
dowj = pd.read_csv('^DJI.csv')
print(dowj.dtypes)
dowj.head()
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object
#          Date         Open         High          Low        Close  \
# 0  2009-01-02  8772.250000  9065.280273  8760.780273  9034.690430
# 1  2009-01-05  9027.129883  9034.370117  8892.360352  8952.889648
# 2  2009-01-06  8954.570313  9088.059570  8940.950195  9015.099609
# 3  2009-01-07  8996.940430  8996.940430  8719.919922  8769.700195
# 4  2009-01-08  8769.940430  8770.019531  8651.190430  8742.459961
#
#      Adj Close     Volume
# 0  9034.690430  213700000
# 1  8952.889648  233760000
# 2  9015.099609  215410000
# 3  8769.700195  266710000
# 4  8742.459961  226620000

# %%
exrate = pd.read_csv('USD_BRL Historical Data.csv')
print(exrate.dtypes)
exrate.head()
# Out:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Change %     object
# dtype: object
#            Date   Price    Open    High     Low Change %
# 0  Apr 19, 2019  3.9275  3.9275  3.9275  3.9275    0.00%
# 1  Apr 18, 2019  3.9274  3.9409  3.9522  3.9047   -0.27%
# 2  Apr 17, 2019  3.9382  3.9052  3.9477  3.8859    0.88%
# 3  Apr 16, 2019  3.9040  3.8730  3.9085  3.8687    0.82%
# 4  Apr 15, 2019  3.8723  3.8811  3.8908  3.8588   -0.25%

# %%
icb = pd.read_excel('Gráfico Historico_ICB.xlsx')
print(icb.dtypes)
icb.head()
# Out:
# Data    datetime64[ns]
# ICB            float64
# dtype: object
#         Data           ICB
# 0 2004-01-02  10000.000000
# 1 2004-01-05  10226.384883
# 2 2004-01-06  10384.872410
# 3 2004-01-07  10288.020286
# 4 2004-01-08  10213.599971

# %% [markdown]
# ### Cleaning

# %%
icb.columns = ['Date', 'ICB']
series=[ibov,dowj,exrate,icb]
for serie in series:
    serie['Date'] = pd.to_datetime(serie['Date'])
    serie.set_index('Date', inplace=True)

# %%
df = ibov.loc[:,['Close']].join(
    dowj.loc[:,['Close']], lsuffix='IBOV', rsuffix='DJI').join(
    exrate.loc[:,['Price']],rsuffix='USDxBRL').join(
    icb).dropna()

# %%
df.head()
# Out:
#             CloseIBOV     CloseDJI   Price           ICB
# Date
# 2009-01-02    40244.0  9034.690430  2.3220  14233.230261
# 2009-01-05    41519.0  8952.889648  2.2365  13896.524465
# 2009-01-06    42312.0  9015.099609  2.1695  13822.557683
# 2009-01-07    40820.0  8769.700195  2.2725  13803.581151
# 2009-01-08    41991.0  8742.459961  2.2955  13877.549904

# %%
#df.to_csv('bicudo_dados.csv')

# %%
df.plot()

# %% [markdown]
# # Data Exploration

# %%
# abordagem: seguir passo a passo da 1a monografia aplicando a metodologia aqui nas series
# meta 1: usar modelos para checar se há significancia para operacao da lavajato
# meta 2: caso a aderencia fique muito bosta, seguir para abordagem usada na 2a monografia pro periodo em questao
# terminar a analise com os resultados - felizes ou nao - e comecar a escrever essa merda

# %% [markdown]
# Car Wash Operations days

# %%
big = ['2014-03-17','2014-04-11','2014-11-14','2015-04-15','2015-06-19','2015-07-28','2015-08-03','2016-02-22',
       '2016-03-04','2016-09-22','2016-09-26','2016-11-17','2017-07-27','2017-08-18','2018-11-23',
       '2014-07-01','2015-01-14','2015-02-05','2015-03-16','2015-03-27','2015-04-10','2018-03-09',#duvida de qual pertence
       '2015-07-02','2015-11-24','2016-03-22','2016-04-12','2016-05-23','2016-05-24','2016-07-04', #duvida de qual pertence
       '2018-05-08','2018-09-26'] #duvida de qual pertence
med = ['2014-03-20','2014-06-11','2014-08-22','2015-05-21','2015-08-13','2015-09-21','2015-11-16','2016-01-27',
       '2016-03-21','2016-04-01','2016-07-07','2016-08-02','2016-11-10','2017-02-23','2017-03-28','2017-05-04',
       '2017-05-26','2017-08-23','2017-10-20','2017-11-21','2018-02-22','2018-03-23','2018-06-21','2018-09-11',
       '2018-09-25','2018-11-05']

# %%
dates=[]
for conj in (big,med):
    for date in conj:
        dates.append(date)

# %%
df['CarWash']= 0
df.loc[df.index.isin(pd.to_datetime(dates)),'CarWash'] = 1

# %%
df['CarWash_big']=0
df.loc[df.index.isin(pd.to_datetime(big)),'CarWash_big'] = 1 
df['CarWash_med']=0
df.loc[df.index.isin(pd.to_datetime(med)),'CarWash_med'] = 1

# %%
df.loc[df.index > '2014-01-01',:'ICB'].plot(figsize = (20,10))
xcoords = df.loc[df.CarWash == 1,:].index
for xc in xcoords:
    plt.axvline(x=xc,color='red')

# %%
df_f = df.loc[df.index > '2014-01-01',:]

# %%
#df_f.to_csv('bicudo_mono_dados.csv')

# %% [markdown]
# ### Data Manipulation

# %%
def tsplot(y, title, lags=None, figsize=(10, 6)):
    fig = plt.figure(figsize=figsize)
    layout = (2, 2)
    ts_ax = plt.subplot2grid(layout, (0, 0))
    hist_ax = plt.subplot2grid(layout, (0, 1))
    acf_ax = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))

    y.plot(ax=ts_ax)
    ts_ax.set_title(title, fontsize=12, fontweight='bold')
    y.plot(ax=hist_ax, kind='hist', bins=25)
    hist_ax.set_title('Histogram')
    sm.tsa.graphics.plot_acf(y, lags=lags, ax=acf_ax)
    sm.tsa.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
    sns.despine()
    plt.tight_layout()
    plt.show()
    return ts_ax, acf_ax, pacf_ax

# %%
df_diff=pd.DataFrame(index=df_f.index)
for column in df_f.loc[:,:'ICB'].columns:
    df_diff[column]=np.log(df_f[column]).diff(6)

# %%
df_diff.dropna(inplace=True)

# %%
df_diff.loc[:,'CloseIBOV'].plot(figsize = (20,10))
for xc in xcoords:
    plt.axvline(x=xc,color='red')

# %%
df_diff['CarWash']= 0
df_diff.loc[df_diff.index.isin(pd.to_datetime(dates)),'CarWash'] = 1 
df_diff['CarWash_big']=0
df_diff.loc[df_diff.index.isin(pd.to_datetime(big)),'CarWash_big'] = 1 
df_diff['CarWash_med']=0
df_diff.loc[df_diff.index.isin(pd.to_datetime(med)),'CarWash_med'] = 1

# %%
df_diff.groupby('CarWash').mean()
# Out:
#          CloseIBOV  CloseDJI     Price       ICB  CarWash_big  CarWash_med
# CarWash
# 0         0.002179  0.002207  0.002495  0.001764      0.00000      0.00000
# 1         0.009051  0.005635  0.001423 -0.001923      0.54902      0.45098

# %%
endog = df_diff.copy()
exog = endog[['CarWash_big','CarWash_med']]

# %%
sm.tsa.stattools.adfuller(endog['CloseIBOV'])
# Out:
# (-6.117821595380988,
#  9.005167220244526e-08,
#  19,
#  1079,
#  {'1%': -3.436425000208065,
#   '5%': -2.864222352544219,
#   '10%': -2.5681981773275466},
#  -5779.035732384554)

# %%
tsplot(endog['CloseIBOV'], 'CloseIBOV')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1c1cd4e9e8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c1ca9d978>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c1d9a8b38>)

# %%
tsplot(endog['CloseDJI'], 'CloseDJI')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1c1cf3c0f0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c1d9dfc50>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c209ffeb8>)

# %%
tsplot(endog['ICB'], 'ICB')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1c1f123dd8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c1e8e75c0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c20838828>)

# %%
tsplot(endog['Price'], 'Price')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1c1e937240>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c1e289278>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c1f2c34e0>)

# %%
mod = sm.tsa.VARMAX(endog[['CloseIBOV', 'CloseDJI', 'ICB', 'Price']], order=(6,0), trend='nc', exog=exog)
res = mod.fit(maxiter=1000, disp=False)
print(res.summary())
# Out:
#                                        Statespace Model Results
# =====================================================================================================
# Dep. Variable:     ['CloseIBOV', 'CloseDJI', 'ICB', 'Price']   No. Observations:                 1104
# Model:                                               VARX(6)   Log Likelihood               14647.124
# Date:                                       Fri, 26 Apr 2019   AIC                         -29066.247
# Time:                                               00:30:49   BIC                         -28495.484
# Sample:                                                    0   HQIC                        -28850.362
#                                                       - 1104
# Covariance Type:                                         opg
# ======================================================================================================
# Ljung-Box (Q):          45.28, 25.65, 25.83, 39.69   Jarque-Bera (JB):   169.32, 448.34, 91.66, 488.42
# Prob(Q):                    0.26, 0.96, 0.96, 0.48   Prob(JB):                  0.00, 0.00, 0.00, 0.00
# Heteroskedasticity (H):     0.68, 1.05, 0.72, 0.74   Skew:                   -0.09, -0.59, 0.23, -0.14
# Prob(H) (two-sided):        0.00, 0.63, 0.00, 0.00   Kurtosis:                  4.91, 5.89, 4.33, 6.25
#                            Results for equation CloseIBOV
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# L1.CloseIBOV        -0.0337      0.027     -1.270      0.204      -0.086       0.018
# L1.CloseDJI         -0.0608      0.043     -1.412      0.158      -0.145       0.024
# L1.ICB              -0.0494      0.064     -0.776      0.438      -0.174       0.075
# L1.Price            -0.1150      0.034     -3.400      0.001      -0.181      -0.049
# L2.CloseIBOV        -0.0659      0.029     -2.278      0.023      -0.123      -0.009
# L2.CloseDJI          0.0856      0.045      1.914      0.056      -0.002       0.173
# L2.ICB              -0.0477      0.059     -0.806      0.421      -0.164       0.068
# L2.Price            -0.0926      0.034     -2.734      0.006      -0.159      -0.026
# L3.CloseIBOV         0.0044      0.029      0.155      0.877      -0.052       0.060
# L3.CloseDJI         -0.0180      0.047     -0.387      0.699      -0.109       0.073
# L3.ICB              -0.0430      0.060     -0.711      0.477      -0.161       0.075
# L3.Price         -3.647e-05      0.039     -0.001      0.999      -0.076       0.076
# L4.CloseIBOV        -0.0042      0.027     -0.156      0.876      -0.057       0.048
# L4.CloseDJI          0.0181      0.051      0.358      0.721      -0.081       0.117
# L4.ICB              -0.0065      0.061     -0.106      0.916      -0.126       0.114
# L4.Price            -0.0149      0.032     -0.471      0.638      -0.077       0.047
# L5.CloseIBOV        -0.0281      0.027     -1.051      0.293      -0.081       0.024
# L5.CloseDJI          0.0643      0.045      1.424      0.154      -0.024       0.153
# L5.ICB               0.0209      0.067      0.314      0.754      -0.110       0.152
# L5.Price            -0.0324      0.037     -0.881      0.378      -0.105       0.040
# L6.CloseIBOV         0.0386      0.028      1.370      0.171      -0.017       0.094
# L6.CloseDJI         -0.0724      0.048     -1.508      0.132      -0.167       0.022
# L6.ICB               0.0336      0.061      0.548      0.584      -0.087       0.154
# L6.Price             0.0207      0.036      0.568      0.570      -0.051       0.092
# beta.CarWash_big     0.0038      0.003      1.285      0.199      -0.002       0.009
# beta.CarWash_med     0.0008      0.003      0.308      0.758      -0.005       0.006
#                                     Error covariance matrix
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# sqrt.var.CloseIBOV              0.0147      0.000     47.330      0.000       0.014       0.015
# sqrt.cov.CloseIBOV.CloseDJI     0.0033      0.000     13.798      0.000       0.003       0.004
# sqrt.var.CloseDJI               0.0073      0.000     58.232      0.000       0.007       0.008
# sqrt.cov.CloseIBOV.ICB         -0.0005      0.000     -2.863      0.004      -0.001      -0.000
# sqrt.cov.CloseDJI.ICB          -0.0005      0.000     -2.586      0.010      -0.001      -0.000
# sqrt.var.ICB                    0.0060      0.000     52.499      0.000       0.006       0.006
# sqrt.cov.CloseIBOV.Price       -0.0049      0.000    -17.668      0.000      -0.005      -0.004
# sqrt.cov.CloseDJI.Price        -0.0012      0.000     -3.654      0.000      -0.002      -0.001
# sqrt.cov.ICB.Price              0.0017      0.000      5.626      0.000       0.001       0.002
# sqrt.var.Price                  0.0092      0.000     56.648      0.000       0.009       0.009
# ===============================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
res.plot_diagnostics()
plt.show()

# %%
ax = res.impulse_responses(10, orthogonalized=True).plot(figsize=(13,3))
ax.set(xlabel='t', title='Responses to a shock to `dln_inv`');
